# %%
a = 3j
print(type(a))
# Out:
# <class 'complex'>

# %%
print(type(a))
# Out:
# <class 'bool'>

# %%
#casting 
b = 34
print(type(b))
c = float(b)
type(c)
# Out:
# <class 'int'>
# float

# %%
print('a')
# Out:
# agr

# %%
print("hello")
# Out:
# h

# %%
print('''Congratulations, you have installed Jupyter Notebook! 
To run the notebook, run the following command at
the Terminal (Mac/Linux) or Command Prompt (Windows):''')
# Out:
# Congratulations, you have installed Jupyter Notebook!
# To run the notebook, run the following command at
# the Terminal (Mac/Linux) or Command Prompt (Windows):

# %%
name = "JOH N FR,AN CI S"
print(name[-4])
# Out:
# C

# %%
Upper_name = name.lower()
print(Upper_name)
# Out:
#    johnfrancis

# %%
print(name.strip())
# Out:
# JOHNFRANCIS

# %%
car = "bmmw"
replace = car.replace("m","j")
print(car)
print(replace)
# Out:
# bmmw
# bjjw

# %%
print(name)
num = 678090
stri = str(num)
split = stri.split("0")
print(split)
# Out:
# JOH N FR,AN CI S
# ['678', '9', '']

# %%
x = "apple"
y = "good"

print(x+ "67" +y)
# Out:
# apple67good

# %%
print((2+2)/2)
# Out:
# 2.0
