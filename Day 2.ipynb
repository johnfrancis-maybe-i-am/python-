# %%
mylist = ["a","b","c","d","e"]
mylist[2]="d"

print(mylist)
# Out:
# ['a', 'b', 'd', 'd', 'e']

# %%
mylist.reverse()
print(mylist)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
list1 = ["hello",45,67.78,4j,True]
list2 = [1,2,3,4,5]
print(list1+list2)
# Out:
# ['hello', 45, 67.78, 4j, True, 1, 2, 3, 4, 5]

# %%
unchange = (45, 67.78, 4j, True, 1)
unchange[3] = False
print(unchange)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-d6a851da2d5d> in <module>
#       1 unchange = (45, 67.78, 4j, True, 1)
# ----> 2 unchange[3] = False
#       3 print(unchange)
#
# TypeError: 'tuple' object does not support item assignment

# %%
car ={"model":"BMW","M_date":2012,"Km":3345}
car.update({"color":"black"})
    
    


print(car)
# Out:
# {'model': 'BMW', 'M_date': 2012, 'Km': 3345, 'color': 'black'}

# %%
num = -67
print(abs(num))
# Out:
# 67

# %%
num = -67

# %%
nam = input("enter a num:")
print(nam)
# Out:
# enter a num: True
# True

# %%
print(type(nam))
# Out:
# <class 'str'>
