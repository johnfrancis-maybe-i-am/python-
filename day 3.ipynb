# %%
celsius = input("enter the temparture: ")

fah = (int(celsius) *(9/5)+32)

print("tempartue in fah is " + str(fah))
# Out:
# enter the temparture:  1
# tempartue in fah is 33.8

# %%
name = "johnfef"
len_name = len(name)
print(len_name)
# Out:
# 7

# %%
name1 = input("Enter a Name : ")
name2 = input("Enter another Name : ")
join = name1 +name2
length = len(join)
key = str(length)
data = {"1":"friend","2":"love","3":"affection","4":"marraige",
       "5":"enemy","6":"sister","7":"friend","8":"love","9":"affection","10":"marraige",
       "11":"enemy","12":"sister"}
print(data.get(key))

# %%
a = 3

b = 5
if a>b:
    print("a id big")
else:
    print("b is big")
