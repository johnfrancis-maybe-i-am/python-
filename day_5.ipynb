# %% [markdown]
# <a href="https://colab.research.google.com/github/johnfrancis-maybe-i-am/python-/blob/main/day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1 = "hellooooo"
list2 = ""

for n in list1:
  if n not in list2:
    list2 = list2 + n

print(list2)
printhello()
# Out:
# helo
# hello world da

# %%
def printhello(fname,lname):
  print("ur first name : "+fname +" , "+"ur last name : "+lname)
 

printhello("john","francis")
# Out:
# 1
# 2
# 3
# 4

# %%
def simple(*item):
  for n in item[:2]:
    print("ur iteams are "+n)

simple("apple","bananna","cherry","cherry","cherry","cherry")
# Out:
# ur iteams are apple
# ur iteams are bananna
